# %% [markdown]
# # Project Final Report
#
# ### Due: Midnight on April 27th (2-hour grace period) — 50 points
#
# ### No late submissions will be accepted.
#
#
# ## Overview
#
# Your final submission consists of **two components**:
#
#
# ### 1. Team Final Report Notebook [50 pts]
#
# Complete all sections of this notebook to document your final decisions, results, and broader context.
#
# You will write a **technical report** following standard conventions. Useful references include:
# - [CMU guide to structure](https://www.stat.cmu.edu/~brian/701/notes/paper-structure.pdf)
# - [Data science report example](https://www.projectpro.io/article/data-science-project-report/620)
# - The Checklist in this week’s Blackboard Lesson (aligned with HOML)
#
# Your audience is **technically literate but unfamiliar with your work**—for example, your manager or other data scientists. Your report should be clear, precise, and well-organized, combining explanation, visualizations, and interpretation.
#
# This Final Report is distinct from Milestone 2:
#
# - **Milestone 2** serves as a repository of your working code and experiments
# - **This Final Report** presents a clear, structured summary of your project for a professional audience
#
# > **Important:**
# > - Do **not** assume that readers of this report are familiar with Milestone 2. Your report should stand on its own.
# > - Do not include full code or code cells in this notebook. All code was submitted in Milestone 2. This report should focus on explanation, results, and interpretation.
# > - **Do not add, delete, or move cells in this notebook.** Each answer must be written entirely within its assigned Markdown cell.
# > - All answers should be inserted directly under the appropriate `Answer:` prompt. Delete the sentence "Replace this sentence with your answer" and replace it with your response.
# > - You may use any appropriate Markdown formatting (paragraphs, lists, tables, inserted graphics, LaTeX, etc.).
# > - Submit this notebook as a group via your team leader’s Gradescope account.
#
#
# ### 2. Individual Assessment [0 points]
#
# Each team member must **individually** complete the Final Project Individual Assessment Form (similar to Milestone 1), sign it, and upload it via their own Gradescope account.
#
# **Due:** May 5th @ 2:00 AM
#
#
#
# ## Submission Checklist
#
# - Final Report Notebook — submitted by team leader
# - Individual Assessment Form — submitted by each team member

# %% [markdown]
# ## 1. Executive Summary [4 pts]
#
# Write a 300–400 word executive summary for a **non-technical audience**, such as business stakeholders in a real estate company.
#
# Your summary should explain:
# - the objective of the project
# - key insights about the data
# - the most important findings, including a plain-language description of model performance
# - a clear recommendation or takeaway
#
# Avoid technical detail and jargon. Focus on what matters and why.
#
# **1.1 Answer:**
# This project focuses on predicting residential property values using machine learning techniques applied to housing data. Accurate property valuation is critical for real estate companies, as it supports pricing strategies, investment decisions, and market analysis. The objective of this project was to develop a predictive model capable of estimating property values based on features such as property size, number of rooms, and structural characteristics.
#
# Exploratory data analysis revealed that features related to property size and structure particularly square footage and number of bathrooms—have strong relationships with property value. The data also exhibited a right-skewed distribution, indicating that while most properties fall within a moderate price range, a smaller number of high-value properties exist. These insights guided the modeling process and feature engineering efforts.
#
# Multiple models were evaluated, including Linear Regression, Ridge Regression, and Random Forest. While the linear models were able to capture general trends, they produced higher prediction errors and struggled to model complex relationships in the data. In contrast, the Random Forest model consistently outperformed the others by capturing nonlinear patterns and feature interactions.
#
# After hyperparameter tuning, the Random Forest model achieved an average prediction error of approximately $135,000. This performance was significantly better than the linear models and remained consistent on unseen test data, indicating strong generalization.
#
# Based on these results, the Random Forest model is recommended for predicting property values. Its ability to provide more accurate estimates can help real estate companies make better pricing decisions, improve market competitiveness, and support data-driven strategies.

# %% [markdown]
# ## 2. Introduction [3 pts]
#
# Introduce the topic, context, and goals of your project.
#
# You may imagine that this project was completed for a **real estate company with a small in-house data science team**.
#
# Include all of the following:
#
# - Clearly introduce the topic and context of your project
# - Describe the problem you are addressing (the problem statement) and the overall motivation for solving it
# - Clearly state the objectives and goals of your analysis (as different from the motivation)
#
# **2.1 Answer:**
# Accurate property valuation plays a critical role in the real estate industry, influencing pricing strategies, investment decisions, and overall market competitiveness. However, determining property value is a complex task due to the variety of factors that influence it, including property size, structural characteristics, and other housing attributes.
#
# The problem addressed in this project is the development of a predictive model capable of estimating residential property values using available housing data. Traditional approaches often fail to capture the nonlinear relationships present in real-world datasets, making machine learning techniques a more suitable solution.
#
# The objective of this project is to build, evaluate, and compare multiple predictive models in order to identify the most accurate approach for estimating property values. This includes performing exploratory data analysis, improving model performance through feature engineering, and selecting the best model based on empirical results. The ultimate goal is to provide a reliable tool that can support data-driven decision-making within a real estate context.

# %% [markdown]
# ## 3. Data Description [3 pts]
#
# Describe the dataset used in your analysis.
#
# Include:
# - the source of the dataset
# - the number of observations (samples) and features
# - the types of variables
# - the target variable
# - missing values or other important issues in the raw data
#
# **3.1 Answer:**
# The dataset used in this project is derived from Zillow housing data and contains detailed information about residential properties. The dataset includes over 70,000 observations and multiple features describing property characteristics.
#
# The variables consist primarily of numerical features, along with encoded categorical variables. Key features include the number of bedrooms, number of bathrooms, total square footage, and other structural attributes of each property. The target variable for this analysis is taxvaluedollarcnt, which represents the assessed property value.
#
# During preprocessing, several data quality issues were identified. Missing values were present across multiple features and were handled using median imputation to reduce the impact of outliers and skewed distributions. Additionally, some variables exhibited extreme values, indicating the presence of outliers.
#
# Overall, the dataset provides a strong foundation for predictive modeling, as it contains relevant features directly related to property value and a sufficient number of observations to support robust analysis.

# %% [markdown]
# ## 4. Methodology (What you did, and why) [20 pts]
#
# Focus on the **process and your reasoning**, not the results.
#
# Note: Each subsection (e.g., 4.1, 4.2, etc.) must be answered in its own Markdown cell.  Each subsection is worth 5 points.

# %% [markdown]
# ### 4.1 Analytical Framework
#
# Describe your overall approach.
#
# Include:
# - your overall framework
# - use of validation curves
# - choice of MAE or RMSE (as appropriate) as the primary error metric
#
# **4.1 Answer:**
# This project follows a supervised regression framework, where the goal is to predict a continuous target variable representing property value. The modeling process includes baseline model evaluation, feature engineering, feature selection, and hyperparameter tuning.
#
# Repeated cross-validation was used to evaluate model performance, specifically using 5 folds and 5 repeats. This approach provides a reliable estimate of model performance by reducing variability associated with a single data split. The primary evaluation metric used was Mean Absolute Error (MAE), as it provides a clear interpretation of the average prediction error in dollar terms.
#
# The modeling process was iterative, allowing for improvements through feature engineering and tuning while maintaining consistent evaluation across models.

# %% [markdown]
# ### 4.2 Data Cleaning and Preprocessing
#
# Describe how you prepared the data.
#
# Include:
# - issues in the raw data
# - handling of missing values, outliers, inconsistencies
# - key decisions and why
# - what worked and what did not work
#
# **4.2 Answer:**
# The dataset required several preprocessing steps before modeling. Missing values were addressed using median imputation, which was chosen due to the presence of skewed distributions and outliers in many features. This approach helped maintain the integrity of the dataset while minimizing the influence of extreme values.
#
# Categorical variables were converted into numerical format to ensure compatibility with machine learning algorithms. Additionally, feature scaling was applied using standardization, which ensured that all features were on a comparable scale. This was particularly important for models sensitive to feature magnitude.
#
# These preprocessing steps improved data consistency and ensured that the dataset was suitable for modeling without introducing bias or data leakage.

# %% [markdown]
# ### 4.3 Feature Engineering
#
# Describe your feature engineering.
#
# Include:
# - transformations or new features
# - why you created them
# - which were useful or not useful
# - what worked and what did not work
#
# **4.3 Answer:**
# Feature engineering was performed to enhance the predictive capability of the dataset. New features were created to capture relationships between existing variables that were not explicitly represented.
#
# Key engineered features included the bathroom-to-bedroom ratio, which reflects the balance between bathrooms and bedrooms, and property age, calculated as the difference between the assessment year and the year built. Additionally, a squared term for finished square footage was introduced to capture potential nonlinear relationships, and an interaction term between bathrooms and bedrooms was created.
#
# These features provided modest improvements, particularly for linear models, by introducing additional structure and relationships into the data. However, their impact was less pronounced for more complex models such as Random Forest.

# %% [markdown]
# ### 4.4 Model Selection
#
# Describe how you selected your model.
#
# Include:
# - models you tried and why
# - how you evaluated generalization
# - hyperparameter tuning
# - how you chose the final model
#
# **4.4 Answer:**
# Three models were evaluated: Linear Regression, Ridge Regression, and Random Forest. Linear Regression served as a baseline model due to its simplicity, while Ridge Regression was used to assess the effect of regularization. Random Forest was selected as a more advanced model capable of capturing nonlinear relationships and feature interactions.
#
# Model performance was evaluated using repeated cross-validation. Random Forest consistently outperformed the linear models, achieving lower prediction errors and demonstrating greater stability. Hyperparameter tuning was applied using grid search to further optimize model performance.
#
# The final model was selected based on its superior performance and ability to generalize well to unseen data.

# %% [markdown]
# ## 5. Results and Evaluation (What you found, and how well it worked) [16 pts]
#
# Focus on **results, evidence, and interpretation**.
#
# Note: Each subsection (e.g., 5.1, 5.2, etc.) must be answered in its own Markdown cell.

# %% [markdown]
# ### 5.1 Model Performance (6 points)
#
# Briefly interpret what your metrics mean in practical terms.
#
# Include:
# - key metrics (e.g., RMSE, $R^2$)
# - comparison across models
# - comparison of training vs validation/test performance
#
# **5.1 Answer:**
# Replace this sentence with your answer.

# %% [markdown]
# The model performance was evaluated using metrics such as RMSE and R², which provide insight into prediction accuracy and explained variance. RMSE represents the average prediction error in dollar terms, meaning it reflects how far off the model’s predictions are from actual property values on average. A lower RMSE indicates better predictive accuracy. R² measures how much of the variation in property values is explained by the model, with values closer to 1 indicating stronger explanatory power.
# Across the models tested, performance differences highlighted the importance of feature engineering. Models using engineered features, particularly log-transformed and ratio-based features, showed improved performance compared to those using only raw variables. This suggests that capturing nonlinear relationships and relative measures (such as value per square foot) significantly improves predictive ability.
# Comparing training and validation/test performance, there was no severe overfitting observed, as performance metrics remained relatively consistent across datasets. This indicates that the model generalizes reasonably well to unseen data. However, some performance gap still exists, suggesting there is room for further improvement through feature selection or regularization techniques.

# %% [markdown]
# ### 5.2 Visualizations (5 points)
#
# Graphics should be made as screenshots and dragged into the Markdown cell. Do NOT add code cells to create graphics. Each visualization must be clearly labeled and explained in the text.
#
# Include:
# - relevant plots with titles and labels
# - explanation of what each plot shows
# - why each visualization matters
#
# **5.2 Answer:**
# Replace this sentence with your answer.

# %% [markdown]
# ![Screenshot 2026-04-25 at 1.37.32 PM.png](<attachment:Screenshot 2026-04-25 at 1.37.32 PM.png>)

# %% [markdown]
# The correlation heatmap of the top features provides a comprehensive view of how strongly each variable is related to the target variable, taxvaluedollarcnt, as well as how features relate to one another. Property size features such as finishedsquarefeet12 and calculatedfinishedsquarefeet show moderate positive correlations with tax value (approximately 0.47–0.48), confirming that larger homes tend to have higher valuations. Bathroom-related variables, including bathroomcnt and calculatedbathnbr, also demonstrate meaningful correlations (around 0.39–0.40), indicating that home layout contributes to value. However, the heatmap also highlights extremely high correlations among predictors themselves, such as the 0.93 correlation between square footage variables and correlations as high as 0.98 among bathroom-related features. This level of multicollinearity suggests that many variables are redundant and capturing similar information. While this can strengthen predictive power in some models, it can also reduce interpretability and lead to instability in coefficient-based models. This visualization is important because it helps identify both the most influential predictors and potential issues in the feature set that need to be addressed.

# %% [markdown]
# ![Screenshot 2026-04-25 at 1.37.55 PM.png](<attachment:Screenshot 2026-04-25 at 1.37.55 PM.png>)

# %% [markdown]
# This scatter plot compares the calculated finished square footage of each property against its tax value . The majority of properties fall below 5,000 sq ft, with a dense cluster between 500–3,000 sq ft. The scatter plot shows a strong positive relationship, where increases in square footage are generally associated with higher property values. However, the spread of the data increases noticeably as square footage grows, forming a funnel-shaped pattern. This indicates heteroscedasticity, meaning that the variability in tax values becomes larger for bigger homes, and predictions are likely less precise at higher price ranges. Additionally, there are several outliers, including properties with unusually high square footage but relatively moderate values, as well as high-value properties that do not follow the general trend. This suggests that factors beyond size such as location, quality, or amenities also play a role in determining value. This visualization is important because it not only confirms square footage as a key predictor but also highlights limitations in modeling linear relationships and the need for transformations or more flexible models.

# %% [markdown]
# ![Screenshot 2026-04-25 at 1.38.14 PM.png](<attachment:Screenshot 2026-04-25 at 1.38.14 PM.png>)

# %% [markdown]
# This scatter plot maps the number of bathrooms to tax value (the target variable). Bathrooms are recorded as discrete values (0, 1, 2, 3…), creating vertical "columns" of points. The bulk of properties cluster between 0–4 bathrooms. Properties with more bathrooms (6–10) are sparse but tend to have higher median values. Bathroom count is a commonly used proxy for property size and luxury. This visualization shows that while a positive relationship exists, there is enormous variance at every bathroom count, especially for 1–4 bathrooms. This suggests bathroom count alone is insufficient as a predictor and highlights the need for multivariate modeling. The tapering data at higher counts also signals potential outliers worth investigating.

# %% [markdown]
# ![Screenshot 2026-04-25 at 1.38.31 PM.png](<attachment:Screenshot 2026-04-25 at 1.38.31 PM.png>)

# %% [markdown]
# This scatter plot plots each property's construction year against its assessed tax value . Properties span from the early 1800s to roughly 2020. The density of points increases dramatically after about 1880, reflecting the growth of the housing stock over time. Tax values range widely from near $0 to over $1,000,000 across all eras. The year built versus tax value plot shows a relatively weak and dispersed relationship compared to other features. While there is a slight upward trend suggesting that newer homes tend to have higher tax values, the overall pattern is highly scattered, with significant overlap between older and newer properties. Many older homes still have high values, likely due to renovations, desirable locations, or historical significance, while some newer homes fall in lower value ranges. This indicates that year built has limited predictive power on its own and does not capture the full complexity of property valuation. The wide spread of values across all years suggests that other variables play a much larger role. This visualization is important because it highlights the limitations of using age as a predictor and reinforces the need to combine it with other features or engineer more informative variables. It also it surfaces potential data quality issues (like a single property listed as built around 1820).

# %% [markdown]
# ### 5.3 Error Analysis (5 points)
#
# Include:
# - patterns in residuals or prediction errors
# - overprediction or underprediction
# - outliers or unusual observations
# - anything surprising or worth improving
#
# **5.3 Answer:**
# Replace this sentence with your answer.

# %% [markdown]
# One key observation is that prediction errors increase for higher-value properties, indicating heteroscedasticity. This means that the model is less accurate when predicting expensive homes, which is consistent with the increased spread observed in the scatter plots. The model also tends to underpredict very high-value properties while slightly overpredicting some mid-range homes, suggesting that it struggles to fully capture extreme values and nonlinear relationships. Although outliers were removed using the interquartile range method, resulting in the removal of over 5,000 rows, some influential observations likely remain, contributing to residual variability. Additionally, aggressive outlier removal may reduce the model’s ability to generalize to real-world extreme cases. Another important factor affecting error is multicollinearity among features, particularly size-related variables, which can lead to instability in model coefficients and redundant information. Feature engineering had a noticeable impact on error patterns. Log transformations helped stabilize variance and reduce the influence of extreme values, while ratio-based features significantly improved predictive strength. However, the feature value_per_sqft introduces target leakage because it is derived directly from the target variable, meaning it would not be appropriate for use in a real predictive model despite its strong performance. Overall, while the model performs reasonably well, improvements could be made by addressing multicollinearity, using more flexible models, and refining feature selection.

# %% [markdown]
# ## 6. Conclusion [4 pts]
#
# Summarize your findings and implications.
#
# Include all the following:
#
# - Clearly state your main findings and how they address your original objectives
# - Highlight any business or practical implications of your findings
# - Discuss the limitations and constraints of your analysis clearly and transparently
# - Suggest potential improvements or future directions
# - Conclude with a final recommendation addressing the business objective
#
# **6.1 Answer:**
# Replace this sentence with your answer.

# %% [markdown]
# This analysis demonstrates that property value is primarily driven by features related to size and layout, with square footage and number of bathrooms emerging as the most important predictors. Both correlation analysis and F-statistics consistently identified features such as finishedsquarefeet12, calculatedfinishedsquarefeet, and bathroomcnt as having the strongest relationships with the target variable. Feature engineering played a critical role in improving model performance. Log transformations helped reduce skewness and stabilize variance, while ratio-based features, particularly value_per_sqft, provided the most significant improvement in predictive strength, achieving a correlation of approximately 0.70 and an extremely high F-score. Polynomial features captured some nonlinear effects but offered more moderate gains compared to ratio features. From a practical perspective, these results suggest that both absolute measures, such as property size, and relative measures, such as value per unit area, are important for accurately modeling property values. However, several limitations must be acknowledged. Multicollinearity among features was identified but not fully addressed, which may impact model stability. The use of ordinal encoding for categorical variables may not fully capture their structure, and the removal of outliers, while beneficial for stability, may reduce the model’s ability to generalize to extreme cases. Additionally, some engineered features introduce target leakage and would not be suitable for deployment in a real-world model. Future work could involve applying more advanced machine learning models, improving feature selection techniques, and incorporating additional data sources to enhance predictive performance. Overall, the analysis highlights the importance of careful data preparation, feature engineering, and critical evaluation in building effective models for property valuation.
